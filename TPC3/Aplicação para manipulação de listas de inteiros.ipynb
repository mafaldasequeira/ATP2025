# %%
#TPC3: Aplicação para manipulação de listas de inteiros

import random
lista=[]
def crialista(N):
    global lista
    lista=[]
    i=1
    while i<=N:
        i+=1
        lista.append(random.randint(1,100))
    return lista

def leLista(N):
    global lista
    lista=[]
    i=0
    while i<N:
        n=int(input("Escreve um número"))
        lista.append(n)
        i=i+1    
    return lista

def somaLista(N):
    global lista
    res=0
    for i in lista:
        res+=i
    return res

def mediaLista(N):
    global lista
    soma=somaLista(lista)
    return soma/len(lista)

def maiorLista(N):
    global lista
    maior=lista[0]
    for elem in lista:
        if elem>maior:
            maior=elem
    return maior

def menorLista(N):
    global lista
    menor=lista[0]
    for elem in lista:
        if elem<menor:
            menor=elem
    return menor

def estaOrdenadaC(N):
    global lista
    for i in range(len(N)-1):
        if N[i]>N[i+1]:
            return "Não"
    return "Sim"

def estaOrdenadaD(N):
    global lista
    for i in range(len(N)-1):
        if N[i]<N[i+1]:
            return "Não"
    return "Sim"

def elemento(N,elem):
    for i in range(len(lista)):
        if lista[i]==elem:
            return i
    return -1

print("""Bem-vindo! O que deseja fazer hoje?:
    * (1) Criar Lista 
    * (2) Ler Lista
    * (3) Soma
    * (4) Média
    * (5) Maior
    * (6) Menor
    * (7) estaOrdenada por ordem crescente
    * (8) estaOrdenada por ordem decrescente
    * (9) Procura um elemento
    * (0) Sair""")

inicio=11

while inicio!=0:
    
    inicio=int(input("Escolha a ação a realizar"))

    if inicio==1:
        print(crialista(int(input("Introduza a quantidade de números que quer na lista"))))

    elif inicio==2:
        print(leLista(int(input("Introduza a quantidade de números que quer na lista"))))

    elif inicio==3:
        print(somaLista(lista)) 

    elif inicio==4:
        print(mediaLista(lista))

    elif inicio==5:
        print(maiorLista(lista))

    elif inicio==6:
        print(menorLista(print))

    elif inicio==7:
        resultado=estaOrdenadaC(lista)
        print(resultado)

    elif inicio==8:
        resultado2=estaOrdenadaD(lista)
        print(resultado)

    elif inicio==9:
        print(lista)
        print(elemento(lista,int(input("Que número deseja encontrar?"))))

    elif inicio==0:
        break

    else:
        print("Tente outro número, de 1 a 9!")
# Out:
# Bem-vindo! O que deseja fazer hoje?:
#     * (1) Criar Lista
#     * (2) Ler Lista
#     * (3) Soma
#     * (4) Média
#     * (5) Maior
#     * (6) Menor
#     * (7) estaOrdenada por ordem crescente
#     * (8) estaOrdenada por ordem decrescente
#     * (9) Procura um elemento
#     * (0) Sair
# [80, 11, 24, 68, 77]
# 260
# 52.0
# 80
# 11
# Não
# Não
# [80, 11, 24, 68, 77]
# 2
# [80, 11, 24, 68, 77]
# -1
